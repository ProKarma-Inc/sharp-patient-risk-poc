# %% [markdown]
# # Explore the reasons RRT events are called
# ### Have Jan 2015 - Aug 2016 loaded in poc_sandbox currently.
# ### Instered in data from Sharp Memorial Hospital

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as datetime
from impala.util import as_pandas
from collections import defaultdict
from operator import itemgetter
import cPickle as pickle
# %matplotlib notebook
plt.style.use('ggplot')

# %%
from impala.dbapi import connect
conn = connect(host="mycluster.domain.com", port=my_impala_port_number)
cur = conn.cursor()
cur.execute("use my_db")

# %% [markdown]
# ### function definitions

# %%
def find_rrt_freq(reasons):
    '''
    reasons is a python list of RRT reasons -- 1 line for each RRT event.
    Each entry is a different RRT event; there may be multiple reasons per event
    output: a pandas dataframe with the counts for each reason.
    '''

    rrt_reasons = defaultdict(int)
    
    for reason in reasons:
        otherreason = ''
        if reason.lower().startswith("other:"):
            # if the line starts with "other" --> the only reason is the otherreason(s)
            otherreason = reason.lower().split('other:')[1]
            rrts = []
        else:
            # if the line contains "other:" or not
            splitreason = reason.lower().split('other:')
            if len(splitreason) > 1:
                # if an "other" reason exists, process it differently
                otherreason = splitreason[1] # text of the line after 'other:'
            primaryreason = splitreason[0].strip().strip('"')
            rrts = primaryreason.split(',')
    
        for rrt in rrts:
            rrt = rrt.strip()
            # loop through list of rrt reasons for patient & add to count tracker
            if len(rrt) > 0:
                # included len check b/c splitting on "other" above caused trailing comma
                if rrt not in rrt_reasons.keys():
                    rrt_reasons[rrt] = 1
                else:
                    rrt_reasons[rrt] += 1
    
    
        if len(otherreason) > 0:
            # handle the "other" reason(s)
            otherreason = "other: " + otherreason.strip().strip('"')
            if otherreason not in rrt_reasons.keys():
                rrt_reasons[otherreason] = 1
            else:
                rrt_reasons[otherreason] += 1
                
#     return rrt_reasons
    return pd.DataFrame(rrt_reasons, index=['count']).transpose().sort_values('count', ascending=False).reset_index()

# %%
def count_others(reasons):
    '''
    Count how many "Other" reasons there are, both occurring alone & with other reasons.
    "other_counts" is a dict which contains "only_other" & "other_withothers" as keys
    '''
    
    other_counts = defaultdict(int)
    other_counts['only_other'] = 0
    other_counts['other_withothers'] = 0

    for reason in reasons:
        if 'other' in reason.lower():
            if reason.lower().startswith('other'):
                other_counts['only_other'] += 1
            else:
                other_counts['other_withothers'] +=1
    
    print other_counts

# %%
def count_staffconcern(reasons):
    '''
    input: list of reasons
    Counts how many time staff concern line happens, both by itself and with other reasons.
    '''

    staff_counts = defaultdict(int)
    staff_counts['by_itself'] = 0
    staff_counts['with_other_reasons'] = 0

    for reason in reasons:
        if 'staff concern' in reason.lower():
            if 'patient,' in reason.lower():
                staff_counts['with_other_reasons'] += 1
            else:
                staff_counts['by_itself'] += 1
    
    print staff_counts

# %%
def avg_num_reasons(reasons):
    '''
    input: list of reasons; each entry is an RRT reason
    ouput: average number of reasons per RRT call.
    '''
    reasoncount = 0.0
    rrtcount = 0.0
    
    for entry in reasons:
        reasoncount += len(entry.split(','))
        rrtcount +=1
        
    return reasoncount/rrtcount

# %% [markdown]
# ## Query impala for rrt reasons
# #### only looking at valid events (ce.valid_until_dt_tm > 4e12) & complete encounters for inpatients (enc.encntr_type_class_cd='391') at Sharp Memorial Hospital (enc.loc_facility_cd='633867')

# %%
query = '''
SELECT ce.event_tag
FROM encounter enc
INNER JOIN clinical_event ce
ON enc.encntr_id = ce.encntr_id
WHERE enc.loc_facility_cd='633867'
AND enc.encntr_complete_dt_tm < 4e12
AND ce.event_cd='54408578'
AND ce.result_status_cd NOT IN ('31', '36')
AND ce.valid_until_dt_tm > 4e12
AND ce.event_class_cd not in ('654645')
AND enc.admit_type_cd !='0'
AND enc.encntr_type_class_cd='391';
'''

cur.execute(query)
# df = as_pandas(cur)  # would read result into pandas df
reasons = cur.fetchall()  # would read result into a list of tuples, e.g. [('Other: iv start',),(...)...]

# %%
# look at the result
reasons
# Out:
# [('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Tachypnea, Other: Increased work of breathing',),
#  ('Chest pain',),
#  ('Changes in LOC',),
#  ('Hypotension, Tachycardia',),
#  ('Tachycardia',),
#  ('Other: blood transfusion reaction',),
#  ('Increased Oxygen Need, Low O2 Saturation, Other: pleuritic pain',),
#  ('Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Blood Sugar',),
#  ('Arrythmias, Blood Sugar',),
#  ('Hypotension',),
#  ('Sepsis event, Tachycardia, Other: febrile >39',),
#  ('Chest pain, Increased Oxygen Need',),
#  ('Changes in LOC, Sepsis event, Tachycardia, Tachypnea',),
#  ('Other: IV START',),
#  ('Tachycardia',),
#  ('Other: hypothermia',),
#  ('Loss of consciousness, Suspected Stroke/Acute',),
#  ('Hypotension',),
#  ('Loss of consciousness',),
#  ('Changes in LOC, Other: stroke code',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Changes in LOC',),
#  ('Arrythmias, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Changes in LOC, Hypotension, Increased Oxygen Need, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Hypotension, Tachypnea',),
#  ('Changes in LOC, Hypotension',),
#  ('Chest pain',),
#  ('Hypertension, Low O2 Saturation, Tachycardia, Other: resp distress.',),
#  ('Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Hypotension',),
#  ('Arrythmias, Hypotension, Tachycardia',),
#  ('Other: pain pump interrogAtion',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Tachypnea, Other: wheezing',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: stridor',),
#  ('Increased Oxygen Need',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Acute Bleeding',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Other: EKG changes',),
#  ('Other: IV start',),
#  ('Blood Sugar, Changes in LOC, Hypotension, Tachypnea',),
#  ('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension, Tachycardia',),
#  ('Other: iv needed for antibiotics',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Hypotension, Tachycardia',),
#  ('Hypotension, Sepsis event',),
#  ('Bradypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation, Tachypnea',),
#  ('Hypotension',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Changes in LOC, Tachycardia, Tachypnea',),
#  ('Other: 2mg IV Neostigmine',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Changes in LOC, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Other: hypotension after beta blockade given for tachycardia HR 155 sustained',),
#  ('Chest pain, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',),
#  ('Other: iv start. difficult. 5 sticks.',),
#  ('Tachycardia',),
#  ('Chest pain',),
#  ('Other: iv start',),
#  ('Changes in LOC',),
#  ('Chest pain',),
#  ('Arrythmias, Chest pain, Other: ST elevation, positive troponin',),
#  ('Chest pain',),
#  ('Changes in LOC, Sepsis event, Tachycardia, Tachypnea, Other: febrile 38',),
#  ('Other: resp. distress',),
#  ('Blood Sugar',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient',),
#  ('Other: IV start',),
#  ('Chest pain, Hypertension',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Other: syncope when standing associated with hypertension',),
#  ('Staff concerned/Worried about Patient, Other: syncopal episode',),
#  ('Changes in LOC, Sepsis event, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Bradycardia',),
#  ('Other: dyspnea/neck swelling',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Other: SEE NOTE',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachypnea',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Chest pain, Other: inexperience with chest tube and atrium',),
#  ('Hypotension',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Other: confusion',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Changes in LOC, Increased Oxygen Need, Tachypnea',),
#  ('Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',),
#  ('Bradycardia, Bradypnea, Increased Oxygen Need, Low O2 Saturation',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Bradycardia, Changes in LOC, Hypotension, Low O2 Saturation, Other: agonal breathing',),
#  ('Bradycardia, Bradypnea, Loss of consciousness',),
#  ('Other: needed NG tube insertion',),
#  ('Other: resp. distress CHF',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Tachycardia',),
#  ('Acute Bleeding',),
#  ('Blood Sugar',),
#  ('Other: Pt states being SOB & wheezing',),
#  ('Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need',),
#  ('Chest pain, Other: abdominal pain',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient',),
#  ('Chest pain',),
#  ('Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Tachycardia',),
#  ('Arrythmias',),
#  ('Increased Oxygen Need',),
#  ('Tachypnea, Other: fever',),
#  ('Other: reaction to gadolinium',),
#  ('Bradycardia',),
#  ('Other: needs PIV',),
#  ('Other: rigors tachycardia',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ('Chest pain',),
#  ('Seizure',),
#  ('Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Tachypnea',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Low O2 Saturation',),
#  ('Tachypnea',),
#  ('Tachycardia',),
#  ('Arrythmias, Tachycardia',),
#  ('Seizure',),
#  ('Other: increased WOB on bipap',),
#  ('Acute Bleeding',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Increased Oxygen Need',),
#  ('Tachycardia',),
#  ('Chest pain, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension, Increased Oxygen Need, Tachypnea',),
#  ('Tachycardia',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Other: strong cough.',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Other: labs',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Changes in LOC, Hypotension',),
#  ('Chest pain',),
#  ('Tachypnea',),
#  ('Other: chf with activity',),
#  ('Chest pain',),
#  ('Tachypnea',),
#  ('Tachycardia',),
#  ('Chest pain',),
#  ('Changes in LOC',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain, Hypertension, Tachycardia, Tachypnea',),
#  ('Tachycardia, Tachypnea',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Other: vagal event',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Chest pain, Tachypnea, Other: SOB',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',),
#  ('Other: resp. decomp.',),
#  ('Other: RRT was looking over chart and discovered tachypnea.',),
#  ('Hypotension',),
#  ('Other: Increased WOB',),
#  ('Arrythmias, Hypertension, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Arrythmias',),
#  ('Increased Oxygen Need, Tachycardia',),
#  ('Arrythmias',),
#  ('Staff concerned/Worried about Patient',),
#  ('Hypotension',),
#  ('Arrythmias',),
#  ('Increased Oxygen Need, Seizure, Other: poor airway protection',),
#  ('Seizure',),
#  ('Changes in LOC',),
#  ('Increased Oxygen Need',),
#  ('Chest pain',),
#  ('Bradypnea, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',),
#  ('Arrythmias, Tachycardia',),
#  ('Hypotension',),
#  ('Changes in LOC',),
#  ('Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Chest pain',),
#  ('Chest pain, Hypertension',),
#  ('Changes in LOC, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Acute Bleeding, Hypotension, Increased Oxygen Need, Tachycardia',),
#  ('Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Other: ? vagal event',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Increased Oxygen Need',),
#  ('Increased Oxygen Need, Other: abd distention',),
#  ('Chest pain',),
#  ('Acute Bleeding',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Bradypnea',),
#  ('Other: post surgical instability.',),
#  ('Bradycardia, Hypotension, Low O2 Saturation, Tachypnea',),
#  ('Changes in LOC, Sepsis event',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Other: To Push Adenosine',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Arrythmias, Tachycardia, Tachypnea',),
#  ('Changes in LOC, Other: resp. decomp.',),
#  ('Staff concerned/Worried about Patient, Other: low UO',),
#  ('Changes in LOC',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ("Tachypnea, Other: current RRT Cathy was in communication with floor Rn's",),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Bradypnea, Changes in LOC',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachypnea, Other: Wheezing',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Arrythmias, Loss of consciousness, Seizure',),
#  ('Acute Bleeding',),
#  ('Loss of consciousness',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Suspected Stroke/Acute',),
#  ('Other: SOB',),
#  ('Changes in LOC, Hypotension',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea, Other: transfusion reaction?',),
#  ('Staff concerned/Worried about Patient, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachypnea',),
#  ('Bradycardia, Hypotension',),
#  ('Hypotension, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Other: sepsis with hemodynamic decompensation',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Tachypnea',),
#  ('Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Suspected Stroke/Acute',),
#  ('Bradycardia, Hypotension, Other: acidosis',),
#  ('Changes in LOC, Other: previous stroke with new neuro changes',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Sepsis event',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Chest pain, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Chest pain',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Chest pain',),
#  ('Chest pain',),
#  ('Arrythmias',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Seizure',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Hypotension',),
#  ('Hypotension, Sepsis event, Tachycardia, Tachypnea, Other: febrile',),
#  ('Tachycardia',),
#  ('Arrythmias, Hypertension, Tachycardia',),
#  ('Chest pain',),
#  ('Arrythmias',),
#  ('Arrythmias',),
#  ('Bradycardia, Changes in LOC',),
#  ('Tachycardia',),
#  ('Staff concerned/Worried about Patient, Other: RRT rounding.',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Other: interagate pain pump',),
#  ('Increased Oxygen Need, Tachypnea, Other: worsening CXR',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Sepsis event',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need',),
#  ('Other: increased WOB',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Arrythmias',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachycardia',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Chest pain, Tachycardia, Other: palpitations',),
#  ('Sepsis event',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Changes in LOC, Loss of consciousness, Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia, Tachypnea',),
#  ('Other: RRT rounds',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Loss of consciousness',),
#  ('Hypotension, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypertension, Tachycardia',),
#  ('Blood Sugar, Changes in LOC, Other: sign. OSA needs bipap/placed',),
#  ('Sepsis event',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Suspected Stroke/Acute',),
#  ('Tachycardia, Tachypnea',),
#  ('Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',),
#  ('Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Arrythmias, Changes in LOC',),
#  ('Staff concerned/Worried about Patient',),
#  ('Other: syncopal episode',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Increased Oxygen Need, Loss of consciousness',),
#  ('Chest pain',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Increased Oxygen Need, Other: SIRS criteria,  infected left foot',),
#  ('Low O2 Saturation, Other: C/O SOB',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Bradycardia',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Blood Sugar',),
#  ('Changes in LOC, Other: stroke code called',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Tachypnea',),
#  ('Bradycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Chest pain, Low O2 Saturation, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Changes in LOC, Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Other: low potassium',),
#  ('Staff concerned/Worried about Patient, Other: anxiety',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Low O2 Saturation, Other: rounding',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Chest pain, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Changes in LOC, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Other: Dr. Sacks request.',),
#  ('Arrythmias',),
#  ('Staff concerned/Worried about Patient, Hypotension, Increased Oxygen Need, Tachycardia',),
#  ('Bradycardia',),
#  ('Tachycardia',),
#  ('Bradypnea, Changes in LOC, Hypotension, Increased Oxygen Need, Loss of consciousness, Low O2 Saturation, Tachycardia',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Chest pain, Other: shivering',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Tachycardia',),
#  ('Chest pain',),
#  ('Changes in LOC, Tachypnea',),
#  ('Tachycardia, Tachypnea, Other: use of accessory mucscles',),
#  ('Arrythmias',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Bradypnea, Changes in LOC',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Increased Oxygen Need',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Acute Bleeding, Low O2 Saturation',),
#  ('Arrythmias, Bradycardia, Increased Oxygen Need, Low O2 Saturation',),
#  ('Arrythmias, Bradycardia, Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia, Tachypnea',),
#  ('Arrythmias',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Tachypnea, Other: abd distention',),
#  ('Changes in LOC, Tachypnea, Other: distended abdomen',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',),
#  ('Hypotension',),
#  ('Low O2 Saturation',),
#  ('Other: suspect air leak to ct',),
#  ('Chest pain',),
#  ('Hypotension',),
#  ('Seizure, Other: Code Blue',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypertension',),
#  ('Tachycardia, Tachypnea',),
#  ('Hypotension',),
#  ('Changes in LOC, Tachycardia',),
#  ('Other: asymptomatic hypovolemia. MD request eval.',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Bradycardia, Other: severe headache',),
#  ('Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Sepsis event',),
#  ('Sepsis event',),
#  ('Hypotension, Sepsis event',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Other: ABG not improving after BiPAP',),
#  ('Changes in LOC',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Hypotension, Increased Oxygen Need',),
#  ('Hypotension, Tachycardia',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Low O2 Saturation, Other: Rigors',),
#  ('Other: Code Blue',),
#  ('Acute Bleeding',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Bradycardia',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Other: pt fell',),
#  ('Seizure',),
#  ('Suspected Stroke/Acute',),
#  ('Tachycardia',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachypnea, Other: wheezing',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Tachypnea',),
#  ('Chest pain, Other: f/u rapid response',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Bradycardia, Bradypnea, Changes in LOC',),
#  ('Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Chest pain',),
#  ('Tachycardia',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Arrythmias, Changes in LOC, Tachycardia',),
#  ('Acute Bleeding, Tachypnea',),
#  ('Tachypnea, Other: likely aspiration',),
#  ('Bradypnea, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Chest pain',),
#  ('Hypotension',),
#  ('Other: Low Hemoglobin',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Increased Oxygen Need, Loss of consciousness, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypertension, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Chest pain, Low O2 Saturation, Tachycardia',),
#  ('Sepsis event',),
#  ('Sepsis event',),
#  ('Sepsis event',),
#  ('Tachycardia, Other: fever, rigors',),
#  ('Hypertension, Tachycardia, Other: decreased urine output',),
#  ('Acute Bleeding',),
#  ('Hypotension, Other: increased pain at proceedure site',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Other: RRT saw complete heartblock in tele.INTERNAL  PACER not CAPTURING.',),
#  ('Bradypnea, Changes in LOC',),
#  ('Changes in LOC',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Other: Respiratory distress.',),
#  ('Staff concerned/Worried about Patient, Hypertension, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Sepsis event, Other: AKF anuric',),
#  ('Staff concerned/Worried about Patient, Hypotension, Tachycardia',),
#  ('Tachypnea',),
#  ('Tachycardia, Other: fever',),
#  ('Acute Bleeding',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Other: heartmate II red heart alarm',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Chest pain, Hypertension',),
#  ('Changes in LOC',),
#  ('Hypotension, Other: sepaia',),
#  ('Hypotension',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea, Other: SIRS',),
#  ('Suspected Stroke/Acute',),
#  ('Other: CTA Cardiac study. required IVP medication',),
#  ('Chest pain',),
#  ("Arrythmias, Hypotension, Tachycardia, Other: NSR to RAF with BP drop to 70's sys",),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Tachycardia, Tachypnea',),
#  ('Bradycardia, Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: respiratory distress',),
#  ('Loss of consciousness',),
#  ('Bradypnea, Loss of consciousness, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Suspected Stroke/Acute',),
#  ('Chest pain',),
#  ('Other: ? vagel event',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Bradycardia',),
#  ('Low O2 Saturation',),
#  ('Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',),
#  ('Arrythmias, Tachycardia',),
#  ('Other: epigastric discomfort',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia',),
#  ('Seizure',),
#  ('Changes in LOC',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient',),
#  ('Suspected Stroke/Acute',),
#  ('Hypertension',),
#  ('Arrythmias, Hypotension',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia',),
#  ('Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',),
#  ('Chest pain, Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Low O2 Saturation',),
#  ('Acute Bleeding',),
#  ('Acute Bleeding, Hypotension',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Chest pain',),
#  ('Suspected Stroke/Acute',),
#  ('Changes in LOC, Hypotension',),
#  ('Loss of consciousness',),
#  ('Arrythmias, Tachycardia',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Hypotension',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Other: Increased hematemesis',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Arrythmias',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Tachycardia',),
#  ('Tachycardia',),
#  ('Changes in LOC, Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Other: increased resp. distress',),
#  ('Staff concerned/Worried about Patient',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypertension',),
#  ('Arrythmias, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia, Other: transfusion reaction',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Sepsis event, Tachypnea',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Seizure',),
#  ('Acute Bleeding, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Arrythmias',),
#  ('Hypotension',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Chest pain, Other: was on floor rounding and heard about pt with chest pain',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Seizure',),
#  ('Chest pain',),
#  ('Other: facial swelling, concern for airway',),
#  ('Bradycardia',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Other: IV drugs given as push',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachycardia',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Blood Sugar, Changes in LOC, Hypotension, Other: coffee ground emesis.   possible aspirations',),
#  ('Hypotension',),
#  ('Blood Sugar, Changes in LOC, Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea, Other: Respiratory Distress',),
#  ('Other: difficult insertion of indwelling catheter',),
#  ('Blood Sugar, Hypotension, Other: sedation',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Other: resp. decompensation',),
#  ('Increased Oxygen Need, Low O2 Saturation, Other: inability to clear airway with suctioning',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Tachycardia, Tachypnea',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Hypotension, Other: aggitation',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: vomitting coffee ground emesis',),
#  ('Hypotension',),
#  ('Chest pain',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension',),
#  ('Other: interrogation of intrathecal pump',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',),
#  ('Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Changes in LOC',),
#  ('Chest pain',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Other: Wheezing',),
#  ('Staff concerned/Worried about Patient',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Loss of consciousness, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Increased Oxygen Need',),
#  ('Low O2 Saturation',),
#  ('Changes in LOC, Low O2 Saturation, Tachypnea',),
#  ('Hypotension',),
#  ('Changes in LOC, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Changes in LOC, Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Changes in LOC, Suspected Stroke/Acute',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Seizure',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Chest pain, Increased Oxygen Need, Tachypnea',),
#  ('Changes in LOC, Tachypnea',),
#  ('Other: high fever with rigors',),
#  ('Tachycardia',),
#  ('Changes in LOC',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Sepsis event',),
#  ('Other: Low SpO2 noted on Tele monitor during RRT rounds.',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Loss of consciousness',),
#  ('Hypotension',),
#  ('Increased Oxygen Need',),
#  ('Other: was checking up on patient who was a RRT earlier this shift',),
#  ('Suspected Stroke/Acute',),
#  ('Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Hypertension, Tachycardia, Tachypnea',),
#  ('Low O2 Saturation, Seizure',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Suspected Stroke/Acute',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Sepsis event, Tachycardia, Other: dyspnea, RR 16',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient, Other: Tongue swelling.',),
#  ('Tachypnea',),
#  ('Hypotension, Loss of consciousness',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Hypotension, Tachycardia',),
#  ('Arrythmias, Hypotension',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Tachypnea, Other: abdominal distension and emesis',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Seizure',),
#  ('Staff concerned/Worried about Patient',),
#  ('Bradycardia, Bradypnea, Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Sepsis event',),
#  ('Tachypnea',),
#  ('Chest pain',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Other: questionable sepsis',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Changes in LOC, Tachycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Hypotension, Loss of consciousness',),
#  ('Staff concerned/Worried about Patient, Loss of consciousness',),
#  ('Hypertension, Tachycardia, Tachypnea, Other:  SOB with acute resp. decomp.',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',),
#  ('Hypotension',),
#  ('Acute Bleeding',),
#  ('Arrythmias, Tachycardia',),
#  ('Other: inadvertent disconnection of epidural cath from iv tubing',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Hypotension',),
#  ('Increased Oxygen Need, Tachycardia, Tachypnea',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Increased Oxygen Need',),
#  ('Arrythmias, Changes in LOC',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient',),
#  ('Other: presumed acute MI.',),
#  ('Sepsis event',),
#  ('Changes in LOC, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Suspected Stroke/Acute',),
#  ('Bradycardia, Hypotension',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Loss of consciousness, Other: GI Bleed',),
#  ('Staff concerned/Worried about Patient, Hypotension, Tachycardia',),
#  ('Other: intrathecal pain pump interrogation',),
#  ('Changes in LOC, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Tachycardia, Tachypnea, Other: Delirium Tremens',),
#  ('Hypertension, Increased Oxygen Need, Other: agonal breathing',),
#  ('Increased Oxygen Need, Low O2 Saturation',),
#  ('Other: resp. decompensation',),
#  ('Other: IV start unsuccessful',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Seizure',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding',),
#  ('Other: IV start',),
#  ('Chest pain, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Changes in LOC, Hypotension',),
#  ('Other: resp. decomp.',),
#  ('Other: intrathecal pain pump interrogation',),
#  ('Low O2 Saturation, Seizure',),
#  ('Other: IV start',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Hypotension',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Seizure',),
#  ('Other: REQUEST NIH SCORING FOR NEW ADMISSION TIA',),
#  ('Staff concerned/Worried about Patient, Other: code blue called for unresponsive patient',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Other: RRT rounding.',),
#  ('Blood Sugar, Hypertension, Low O2 Saturation, Tachypnea, Other: delirium tremens',),
#  ('Seizure',),
#  ('Hypotension',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Arrythmias, Hypotension, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Bradycardia',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Other: iv start',),
#  ('Hypotension, Increased Oxygen Need, Tachycardia, Other: dehydrated',),
#  ('Arrythmias',),
#  ('Other: possible retained oral foreign body',),
#  ('Changes in LOC',),
#  ('Blood Sugar, Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding, Changes in LOC, Hypotension',),
#  ('Hypotension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Bradycardia',),
#  ('Staff concerned/Worried about Patient',),
#  ('Other: iv start',),
#  ('Changes in LOC, Low O2 Saturation',),
#  ('Changes in LOC, Tachypnea, Other: FEBRILE',),
#  ('Changes in LOC, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Tachypnea, Other: increased WOB',),
#  ('Other: pain pump interrogation',),
#  ('Changes in LOC, Hypotension, Low O2 Saturation, Sepsis event, Tachycardia',),
#  ('Bradycardia, Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Blood Sugar, Changes in LOC',),
#  ('Chest pain',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Tachycardia, Tachypnea',),
#  ('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Other: AGITATION',),
#  ('Staff concerned/Worried about Patient, Tachypnea, Other: increased WOB with irregular breathing pattern.',),
#  ('Staff concerned/Worried about Patient',),
#  ('Arrythmias, Chest pain',),
#  ('Hypotension',),
#  ('Hypotension',),
#  ('Hypotension, Other: ESRD',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Suspected Stroke/Acute, Tachycardia',),
#  ('Low O2 Saturation',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Changes in LOC',),
#  ('Changes in LOC, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Hypotension, Sepsis event',),
#  ('Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachypnea',),
#  ('Hypotension',),
#  ('Chest pain, Hypotension, Other: electrolyte imbalance: critically low calcium 5 and albumin 1.6',),
#  ('Sepsis event',),
#  ('Hypotension, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Other: copious secretions but pt. unable to expectorate.  requiring NT suction.',),
#  ('Other: iv start for antibiotics',),
#  ('Other: requesting IV start',),
#  ('Acute Bleeding, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Seizure',),
#  ('Arrythmias',),
#  ('Arrythmias',),
#  ('Staff concerned/Worried about Patient, Suspected Stroke/Acute',),
#  ('Staff concerned/Worried about Patient, Bradypnea',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Seizure',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding',),
#  ('Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Bradypnea, Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Bradycardia, Hypotension, Increased Oxygen Need, Low O2 Saturation',),
#  ('Arrythmias',),
#  ('Seizure',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia',),
#  ('Arrythmias',),
#  ('Arrythmias',),
#  ('Hypotension',),
#  ('Chest pain',),
#  ('Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea, Other: SIRS criteria',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient',),
#  ('Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',),
#  ('Staff concerned/Worried about Patient, Other: low H/H',),
#  ('Hypotension, Sepsis event',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Other: SOB with chest tightness',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Seizure',),
#  ('Other: iv start',),
#  ('Other: RAF',),
#  ('Changes in LOC, Hypotension, Increased Oxygen Need, Sepsis event',),
#  ('Hypertension, Tachypnea',),
#  ('Hypotension',),
#  ('Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Arrythmias, Tachycardia',),
#  ('Hypotension, Sepsis event, Tachycardia',),
#  ('Hypertension, Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',),
#  ('Hypertension, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Tachypnea',),
#  ('Hypotension, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Chest pain',),
#  ('Hypotension, Sepsis event, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypertension',),
#  ('Low O2 Saturation',),
#  ('Other: iv',),
#  ('Other: fever with rigors',),
#  ('Other: pain pump interrogation',),
#  ('Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',),
#  ('Bradycardia',),
#  ('Staff concerned/Worried about Patient, Arrythmias',),
#  ('Other: iv start',),
#  ('Hypotension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',),
#  ('Changes in LOC',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Staff concerned/Worried about Patient, Changes in LOC, Loss of consciousness, Sepsis event',),
#  ('Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea',),
#  ('Other: iv start attempted',),
#  ('Changes in LOC',),
#  ('Other: tele tech noted that there was some ST changes.  alerted primary RN as well as RRT.',),
#  ('Sepsis event',),
#  ('Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia',),
#  ('Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Hypotension, Tachycardia',),
#  ('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Chest pain, Increased Oxygen Need',),
#  ('Other: iv start',),
#  ('Staff concerned/Worried about Patient, Hypertension',),
#  ('Staff concerned/Worried about Patient, Tachycardia',),
#  ('Hypotension',),
#  ('Staff concerned/Worried about Patient',),
#  ('Increased Oxygen Need, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Hypotension',),
#  ('Other: IV START',),
#  ('Other: iv start',),
#  ('Other: iv start',),
#  ('Chest pain, Tachycardia, Tachypnea',),
#  ('Staff concerned/Worried about Patient, Low O2 Saturation',),
#  ('Other: ST depression and t wave inversion',),
#  ('Hypertension, Other: iv start',),
#  ('Staff concerned/Worried about Patient, Sepsis event, Tachycardia',),
#  ('Hypertension',),
#  ('Hypotension, Tachycardia',),
#  ('Other: Dressing change',),
#  ...]

# %%
# Make the tuple within a list a simple list
reasons = [reason[0] for reason in reasons]

# %%
reasons
# Out:
# ['Other: iv start',
#  'Staff concerned/Worried about Patient, Tachypnea, Other: Increased work of breathing',
#  'Chest pain',
#  'Changes in LOC',
#  'Hypotension, Tachycardia',
#  'Tachycardia',
#  'Other: blood transfusion reaction',
#  'Increased Oxygen Need, Low O2 Saturation, Other: pleuritic pain',
#  'Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Blood Sugar',
#  'Arrythmias, Blood Sugar',
#  'Hypotension',
#  'Sepsis event, Tachycardia, Other: febrile >39',
#  'Chest pain, Increased Oxygen Need',
#  'Changes in LOC, Sepsis event, Tachycardia, Tachypnea',
#  'Other: IV START',
#  'Tachycardia',
#  'Other: hypothermia',
#  'Loss of consciousness, Suspected Stroke/Acute',
#  'Hypotension',
#  'Loss of consciousness',
#  'Changes in LOC, Other: stroke code',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Changes in LOC',
#  'Arrythmias, Tachycardia',
#  'Staff concerned/Worried about Patient, Arrythmias, Changes in LOC, Hypotension, Increased Oxygen Need, Tachycardia',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Hypotension, Tachypnea',
#  'Changes in LOC, Hypotension',
#  'Chest pain',
#  'Hypertension, Low O2 Saturation, Tachycardia, Other: resp distress.',
#  'Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Hypotension',
#  'Arrythmias, Hypotension, Tachycardia',
#  'Other: pain pump interrogAtion',
#  'Staff concerned/Worried about Patient, Changes in LOC, Tachypnea, Other: wheezing',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: stridor',
#  'Increased Oxygen Need',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Acute Bleeding',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Other: EKG changes',
#  'Other: IV start',
#  'Blood Sugar, Changes in LOC, Hypotension, Tachypnea',
#  'Other: iv start',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension, Tachycardia',
#  'Other: iv needed for antibiotics',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Hypotension, Tachycardia',
#  'Hypotension, Sepsis event',
#  'Bradypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation, Tachypnea',
#  'Hypotension',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Changes in LOC, Tachycardia, Tachypnea',
#  'Other: 2mg IV Neostigmine',
#  'Increased Oxygen Need, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Changes in LOC, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Other: hypotension after beta blockade given for tachycardia HR 155 sustained',
#  'Chest pain, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',
#  'Other: iv start. difficult. 5 sticks.',
#  'Tachycardia',
#  'Chest pain',
#  'Other: iv start',
#  'Changes in LOC',
#  'Chest pain',
#  'Arrythmias, Chest pain, Other: ST elevation, positive troponin',
#  'Chest pain',
#  'Changes in LOC, Sepsis event, Tachycardia, Tachypnea, Other: febrile 38',
#  'Other: resp. distress',
#  'Blood Sugar',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Chest pain',
#  'Staff concerned/Worried about Patient',
#  'Other: IV start',
#  'Chest pain, Hypertension',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Changes in LOC, Other: syncope when standing associated with hypertension',
#  'Staff concerned/Worried about Patient, Other: syncopal episode',
#  'Changes in LOC, Sepsis event, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Bradycardia',
#  'Other: dyspnea/neck swelling',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Other: SEE NOTE',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Increased Oxygen Need, Tachypnea',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient',
#  'Tachypnea',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Chest pain, Other: inexperience with chest tube and atrium',
#  'Hypotension',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Other: confusion',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Changes in LOC, Increased Oxygen Need, Tachypnea',
#  'Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',
#  'Bradycardia, Bradypnea, Increased Oxygen Need, Low O2 Saturation',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Bradycardia, Changes in LOC, Hypotension, Low O2 Saturation, Other: agonal breathing',
#  'Bradycardia, Bradypnea, Loss of consciousness',
#  'Other: needed NG tube insertion',
#  'Other: resp. distress CHF',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Arrythmias, Tachycardia',
#  'Acute Bleeding',
#  'Blood Sugar',
#  'Other: Pt states being SOB & wheezing',
#  'Increased Oxygen Need',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need',
#  'Chest pain, Other: abdominal pain',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient',
#  'Chest pain',
#  'Increased Oxygen Need',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Tachycardia',
#  'Arrythmias',
#  'Increased Oxygen Need',
#  'Tachypnea, Other: fever',
#  'Other: reaction to gadolinium',
#  'Bradycardia',
#  'Other: needs PIV',
#  'Other: rigors tachycardia',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  'Chest pain',
#  'Seizure',
#  'Increased Oxygen Need',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Tachypnea',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Low O2 Saturation',
#  'Tachypnea',
#  'Tachycardia',
#  'Arrythmias, Tachycardia',
#  'Seizure',
#  'Other: increased WOB on bipap',
#  'Acute Bleeding',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Increased Oxygen Need',
#  'Tachycardia',
#  'Chest pain, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension, Increased Oxygen Need, Tachypnea',
#  'Tachycardia',
#  'Increased Oxygen Need, Tachypnea',
#  'Other: strong cough.',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Other: labs',
#  'Hypotension',
#  'Hypotension',
#  'Changes in LOC, Hypotension',
#  'Chest pain',
#  'Tachypnea',
#  'Other: chf with activity',
#  'Chest pain',
#  'Tachypnea',
#  'Tachycardia',
#  'Chest pain',
#  'Changes in LOC',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain, Hypertension, Tachycardia, Tachypnea',
#  'Tachycardia, Tachypnea',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Other: vagal event',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Chest pain, Tachypnea, Other: SOB',
#  'Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',
#  'Other: resp. decomp.',
#  'Other: RRT was looking over chart and discovered tachypnea.',
#  'Hypotension',
#  'Other: Increased WOB',
#  'Arrythmias, Hypertension, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Arrythmias',
#  'Increased Oxygen Need, Tachycardia',
#  'Arrythmias',
#  'Staff concerned/Worried about Patient',
#  'Hypotension',
#  'Arrythmias',
#  'Increased Oxygen Need, Seizure, Other: poor airway protection',
#  'Seizure',
#  'Changes in LOC',
#  'Increased Oxygen Need',
#  'Chest pain',
#  'Bradypnea, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',
#  'Arrythmias, Tachycardia',
#  'Hypotension',
#  'Changes in LOC',
#  'Increased Oxygen Need',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Chest pain',
#  'Chest pain, Hypertension',
#  'Changes in LOC, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Acute Bleeding, Hypotension, Increased Oxygen Need, Tachycardia',
#  'Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Other: ? vagal event',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Increased Oxygen Need',
#  'Increased Oxygen Need, Other: abd distention',
#  'Chest pain',
#  'Acute Bleeding',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Bradypnea',
#  'Other: post surgical instability.',
#  'Bradycardia, Hypotension, Low O2 Saturation, Tachypnea',
#  'Changes in LOC, Sepsis event',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Other: To Push Adenosine',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Arrythmias, Tachycardia, Tachypnea',
#  'Changes in LOC, Other: resp. decomp.',
#  'Staff concerned/Worried about Patient, Other: low UO',
#  'Changes in LOC',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  "Tachypnea, Other: current RRT Cathy was in communication with floor Rn's",
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Bradypnea, Changes in LOC',
#  'Staff concerned/Worried about Patient',
#  'Tachypnea, Other: Wheezing',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Arrythmias, Loss of consciousness, Seizure',
#  'Acute Bleeding',
#  'Loss of consciousness',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Suspected Stroke/Acute',
#  'Other: SOB',
#  'Changes in LOC, Hypotension',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea, Other: transfusion reaction?',
#  'Staff concerned/Worried about Patient, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Tachypnea',
#  'Bradycardia, Hypotension',
#  'Hypotension, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Other: sepsis with hemodynamic decompensation',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Tachypnea',
#  'Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Suspected Stroke/Acute',
#  'Bradycardia, Hypotension, Other: acidosis',
#  'Changes in LOC, Other: previous stroke with new neuro changes',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Sepsis event',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Chest pain, Tachycardia',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Low O2 Saturation, Tachycardia, Tachypnea',
#  'Chest pain',
#  'Hypotension',
#  'Hypotension',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Chest pain',
#  'Chest pain',
#  'Arrythmias',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Seizure',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Hypotension',
#  'Hypotension, Sepsis event, Tachycardia, Tachypnea, Other: febrile',
#  'Tachycardia',
#  'Arrythmias, Hypertension, Tachycardia',
#  'Chest pain',
#  'Arrythmias',
#  'Arrythmias',
#  'Bradycardia, Changes in LOC',
#  'Tachycardia',
#  'Staff concerned/Worried about Patient, Other: RRT rounding.',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Other: interagate pain pump',
#  'Increased Oxygen Need, Tachypnea, Other: worsening CXR',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Sepsis event',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need',
#  'Other: increased WOB',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Arrythmias',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Tachycardia',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Chest pain, Tachycardia, Other: palpitations',
#  'Sepsis event',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Changes in LOC, Loss of consciousness, Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia, Tachypnea',
#  'Other: RRT rounds',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Loss of consciousness',
#  'Hypotension, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypertension, Tachycardia',
#  'Blood Sugar, Changes in LOC, Other: sign. OSA needs bipap/placed',
#  'Sepsis event',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Suspected Stroke/Acute',
#  'Tachycardia, Tachypnea',
#  'Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',
#  'Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Arrythmias, Changes in LOC',
#  'Staff concerned/Worried about Patient',
#  'Other: syncopal episode',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Increased Oxygen Need, Loss of consciousness',
#  'Chest pain',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Increased Oxygen Need, Other: SIRS criteria,  infected left foot',
#  'Low O2 Saturation, Other: C/O SOB',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Bradycardia',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Blood Sugar',
#  'Changes in LOC, Other: stroke code called',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Tachypnea',
#  'Bradycardia',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Chest pain, Low O2 Saturation, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Changes in LOC, Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Other: low potassium',
#  'Staff concerned/Worried about Patient, Other: anxiety',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Low O2 Saturation, Other: rounding',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Chest pain, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Changes in LOC, Tachypnea',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Other: Dr. Sacks request.',
#  'Arrythmias',
#  'Staff concerned/Worried about Patient, Hypotension, Increased Oxygen Need, Tachycardia',
#  'Bradycardia',
#  'Tachycardia',
#  'Bradypnea, Changes in LOC, Hypotension, Increased Oxygen Need, Loss of consciousness, Low O2 Saturation, Tachycardia',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Chest pain, Other: shivering',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Arrythmias, Tachycardia',
#  'Chest pain',
#  'Changes in LOC, Tachypnea',
#  'Tachycardia, Tachypnea, Other: use of accessory mucscles',
#  'Arrythmias',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  'Chest pain',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Bradypnea, Changes in LOC',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Increased Oxygen Need',
#  'Low O2 Saturation, Tachypnea',
#  'Acute Bleeding, Low O2 Saturation',
#  'Arrythmias, Bradycardia, Increased Oxygen Need, Low O2 Saturation',
#  'Arrythmias, Bradycardia, Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia, Tachypnea',
#  'Arrythmias',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Tachypnea, Other: abd distention',
#  'Changes in LOC, Tachypnea, Other: distended abdomen',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachypnea',
#  'Hypotension',
#  'Low O2 Saturation',
#  'Other: suspect air leak to ct',
#  'Chest pain',
#  'Hypotension',
#  'Seizure, Other: Code Blue',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Hypertension',
#  'Tachycardia, Tachypnea',
#  'Hypotension',
#  'Changes in LOC, Tachycardia',
#  'Other: asymptomatic hypovolemia. MD request eval.',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Bradycardia, Other: severe headache',
#  'Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Sepsis event',
#  'Sepsis event',
#  'Hypotension, Sepsis event',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Other: ABG not improving after BiPAP',
#  'Changes in LOC',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Hypotension, Increased Oxygen Need',
#  'Hypotension, Tachycardia',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Low O2 Saturation, Other: Rigors',
#  'Other: Code Blue',
#  'Acute Bleeding',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Bradycardia',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Other: pt fell',
#  'Seizure',
#  'Suspected Stroke/Acute',
#  'Tachycardia',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Tachypnea, Other: wheezing',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Tachypnea',
#  'Chest pain, Other: f/u rapid response',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Bradycardia, Bradypnea, Changes in LOC',
#  'Hypotension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Chest pain',
#  'Tachycardia',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Arrythmias, Changes in LOC, Tachycardia',
#  'Acute Bleeding, Tachypnea',
#  'Tachypnea, Other: likely aspiration',
#  'Bradypnea, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Chest pain',
#  'Hypotension',
#  'Other: Low Hemoglobin',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Increased Oxygen Need, Loss of consciousness, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypertension, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Chest pain, Low O2 Saturation, Tachycardia',
#  'Sepsis event',
#  'Sepsis event',
#  'Sepsis event',
#  'Tachycardia, Other: fever, rigors',
#  'Hypertension, Tachycardia, Other: decreased urine output',
#  'Acute Bleeding',
#  'Hypotension, Other: increased pain at proceedure site',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Other: RRT saw complete heartblock in tele.INTERNAL  PACER not CAPTURING.',
#  'Bradypnea, Changes in LOC',
#  'Changes in LOC',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Other: Respiratory distress.',
#  'Staff concerned/Worried about Patient, Hypertension, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Sepsis event, Other: AKF anuric',
#  'Staff concerned/Worried about Patient, Hypotension, Tachycardia',
#  'Tachypnea',
#  'Tachycardia, Other: fever',
#  'Acute Bleeding',
#  'Hypotension',
#  'Hypotension',
#  'Other: heartmate II red heart alarm',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Chest pain, Hypertension',
#  'Changes in LOC',
#  'Hypotension, Other: sepaia',
#  'Hypotension',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea, Other: SIRS',
#  'Suspected Stroke/Acute',
#  'Other: CTA Cardiac study. required IVP medication',
#  'Chest pain',
#  "Arrythmias, Hypotension, Tachycardia, Other: NSR to RAF with BP drop to 70's sys",
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Low O2 Saturation, Tachypnea',
#  'Tachycardia, Tachypnea',
#  'Bradycardia, Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: respiratory distress',
#  'Loss of consciousness',
#  'Bradypnea, Loss of consciousness, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Suspected Stroke/Acute',
#  'Chest pain',
#  'Other: ? vagel event',
#  'Staff concerned/Worried about Patient, Arrythmias, Bradycardia',
#  'Low O2 Saturation',
#  'Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',
#  'Arrythmias, Tachycardia',
#  'Other: epigastric discomfort',
#  'Hypotension',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia',
#  'Seizure',
#  'Changes in LOC',
#  'Increased Oxygen Need, Tachypnea',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient',
#  'Suspected Stroke/Acute',
#  'Hypertension',
#  'Arrythmias, Hypotension',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia',
#  'Increased Oxygen Need',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',
#  'Chest pain, Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Low O2 Saturation',
#  'Acute Bleeding',
#  'Acute Bleeding, Hypotension',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Chest pain',
#  'Suspected Stroke/Acute',
#  'Changes in LOC, Hypotension',
#  'Loss of consciousness',
#  'Arrythmias, Tachycardia',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Hypotension',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia',
#  'Increased Oxygen Need, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Other: Increased hematemesis',
#  'Increased Oxygen Need, Tachypnea',
#  'Arrythmias',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Arrythmias, Tachycardia',
#  'Tachycardia',
#  'Changes in LOC, Hypotension',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Other: increased resp. distress',
#  'Staff concerned/Worried about Patient',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypertension',
#  'Arrythmias, Tachycardia',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia, Other: transfusion reaction',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Sepsis event, Tachypnea',
#  'Increased Oxygen Need, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Seizure',
#  'Acute Bleeding, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Arrythmias',
#  'Hypotension',
#  'Low O2 Saturation, Tachypnea',
#  'Chest pain, Other: was on floor rounding and heard about pt with chest pain',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Seizure',
#  'Chest pain',
#  'Other: facial swelling, concern for airway',
#  'Bradycardia',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Hypotension',
#  'Hypotension',
#  'Other: IV drugs given as push',
#  'Staff concerned/Worried about Patient',
#  'Tachycardia',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Blood Sugar, Changes in LOC, Hypotension, Other: coffee ground emesis.   possible aspirations',
#  'Hypotension',
#  'Blood Sugar, Changes in LOC, Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea, Other: Respiratory Distress',
#  'Other: difficult insertion of indwelling catheter',
#  'Blood Sugar, Hypotension, Other: sedation',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Other: resp. decompensation',
#  'Increased Oxygen Need, Low O2 Saturation, Other: inability to clear airway with suctioning',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension, Tachycardia, Tachypnea',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Staff concerned/Worried about Patient, Arrythmias, Hypotension, Other: aggitation',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea, Other: vomitting coffee ground emesis',
#  'Hypotension',
#  'Chest pain',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension',
#  'Other: interrogation of intrathecal pump',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Acute Bleeding',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia',
#  'Hypotension',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',
#  'Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Low O2 Saturation, Tachypnea',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Low O2 Saturation, Tachypnea',
#  'Changes in LOC',
#  'Chest pain',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Other: Wheezing',
#  'Staff concerned/Worried about Patient',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Loss of consciousness, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Increased Oxygen Need',
#  'Low O2 Saturation',
#  'Changes in LOC, Low O2 Saturation, Tachypnea',
#  'Hypotension',
#  'Changes in LOC, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Changes in LOC, Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Changes in LOC, Suspected Stroke/Acute',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC, Seizure',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Chest pain, Increased Oxygen Need, Tachypnea',
#  'Changes in LOC, Tachypnea',
#  'Other: high fever with rigors',
#  'Tachycardia',
#  'Changes in LOC',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Sepsis event',
#  'Other: Low SpO2 noted on Tele monitor during RRT rounds.',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Loss of consciousness',
#  'Hypotension',
#  'Increased Oxygen Need',
#  'Other: was checking up on patient who was a RRT earlier this shift',
#  'Suspected Stroke/Acute',
#  'Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Hypertension, Tachycardia, Tachypnea',
#  'Low O2 Saturation, Seizure',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Suspected Stroke/Acute',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Sepsis event, Tachycardia, Other: dyspnea, RR 16',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient, Other: Tongue swelling.',
#  'Tachypnea',
#  'Hypotension, Loss of consciousness',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Arrythmias, Hypotension, Tachycardia',
#  'Arrythmias, Hypotension',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Tachypnea, Other: abdominal distension and emesis',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient, Changes in LOC, Seizure',
#  'Staff concerned/Worried about Patient',
#  'Bradycardia, Bradypnea, Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Sepsis event',
#  'Tachypnea',
#  'Chest pain',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Other: questionable sepsis',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Changes in LOC, Tachycardia',
#  'Staff concerned/Worried about Patient',
#  'Hypotension, Loss of consciousness',
#  'Staff concerned/Worried about Patient, Loss of consciousness',
#  'Hypertension, Tachycardia, Tachypnea, Other:  SOB with acute resp. decomp.',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachypnea',
#  'Hypotension',
#  'Acute Bleeding',
#  'Arrythmias, Tachycardia',
#  'Other: inadvertent disconnection of epidural cath from iv tubing',
#  'Staff concerned/Worried about Patient, Changes in LOC, Hypotension',
#  'Increased Oxygen Need, Tachycardia, Tachypnea',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Increased Oxygen Need',
#  'Arrythmias, Changes in LOC',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC, Low O2 Saturation',
#  'Staff concerned/Worried about Patient',
#  'Other: presumed acute MI.',
#  'Sepsis event',
#  'Changes in LOC, Tachypnea',
#  'Staff concerned/Worried about Patient, Suspected Stroke/Acute',
#  'Bradycardia, Hypotension',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Loss of consciousness, Other: GI Bleed',
#  'Staff concerned/Worried about Patient, Hypotension, Tachycardia',
#  'Other: intrathecal pain pump interrogation',
#  'Changes in LOC, Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Tachycardia, Tachypnea, Other: Delirium Tremens',
#  'Hypertension, Increased Oxygen Need, Other: agonal breathing',
#  'Increased Oxygen Need, Low O2 Saturation',
#  'Other: resp. decompensation',
#  'Other: IV start unsuccessful',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Seizure',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Acute Bleeding',
#  'Other: IV start',
#  'Chest pain, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Changes in LOC, Hypotension',
#  'Other: resp. decomp.',
#  'Other: intrathecal pain pump interrogation',
#  'Low O2 Saturation, Seizure',
#  'Other: IV start',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Hypotension',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Changes in LOC, Seizure',
#  'Other: REQUEST NIH SCORING FOR NEW ADMISSION TIA',
#  'Staff concerned/Worried about Patient, Other: code blue called for unresponsive patient',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Other: RRT rounding.',
#  'Blood Sugar, Hypertension, Low O2 Saturation, Tachypnea, Other: delirium tremens',
#  'Seizure',
#  'Hypotension',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Arrythmias, Hypotension, Tachycardia',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Bradycardia',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Other: iv start',
#  'Hypotension, Increased Oxygen Need, Tachycardia, Other: dehydrated',
#  'Arrythmias',
#  'Other: possible retained oral foreign body',
#  'Changes in LOC',
#  'Blood Sugar, Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Acute Bleeding, Changes in LOC, Hypotension',
#  'Hypotension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Bradycardia',
#  'Staff concerned/Worried about Patient',
#  'Other: iv start',
#  'Changes in LOC, Low O2 Saturation',
#  'Changes in LOC, Tachypnea, Other: FEBRILE',
#  'Changes in LOC, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Other: iv start',
#  'Staff concerned/Worried about Patient, Tachypnea, Other: increased WOB',
#  'Other: pain pump interrogation',
#  'Changes in LOC, Hypotension, Low O2 Saturation, Sepsis event, Tachycardia',
#  'Bradycardia, Hypotension',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Blood Sugar, Changes in LOC',
#  'Chest pain',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Tachycardia, Tachypnea',
#  'Other: iv start',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Changes in LOC, Increased Oxygen Need, Low O2 Saturation, Other: AGITATION',
#  'Staff concerned/Worried about Patient, Tachypnea, Other: increased WOB with irregular breathing pattern.',
#  'Staff concerned/Worried about Patient',
#  'Arrythmias, Chest pain',
#  'Hypotension',
#  'Hypotension',
#  'Hypotension, Other: ESRD',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Changes in LOC, Suspected Stroke/Acute, Tachycardia',
#  'Low O2 Saturation',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Changes in LOC',
#  'Changes in LOC, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Hypotension, Sepsis event',
#  'Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachypnea',
#  'Hypotension',
#  'Chest pain, Hypotension, Other: electrolyte imbalance: critically low calcium 5 and albumin 1.6',
#  'Sepsis event',
#  'Hypotension, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Other: copious secretions but pt. unable to expectorate.  requiring NT suction.',
#  'Other: iv start for antibiotics',
#  'Other: requesting IV start',
#  'Acute Bleeding, Low O2 Saturation',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC, Seizure',
#  'Arrythmias',
#  'Arrythmias',
#  'Staff concerned/Worried about Patient, Suspected Stroke/Acute',
#  'Staff concerned/Worried about Patient, Bradypnea',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Seizure',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Acute Bleeding',
#  'Staff concerned/Worried about Patient, Acute Bleeding, Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Bradypnea, Changes in LOC',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Bradycardia, Hypotension, Increased Oxygen Need, Low O2 Saturation',
#  'Arrythmias',
#  'Seizure',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia',
#  'Arrythmias',
#  'Arrythmias',
#  'Hypotension',
#  'Chest pain',
#  'Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea, Other: SIRS criteria',
#  'Staff concerned/Worried about Patient, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient',
#  'Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Increased Oxygen Need, Low O2 Saturation',
#  'Staff concerned/Worried about Patient, Other: low H/H',
#  'Hypotension, Sepsis event',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Other: SOB with chest tightness',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Seizure',
#  'Other: iv start',
#  'Other: RAF',
#  'Changes in LOC, Hypotension, Increased Oxygen Need, Sepsis event',
#  'Hypertension, Tachypnea',
#  'Hypotension',
#  'Increased Oxygen Need, Low O2 Saturation, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Arrythmias, Tachycardia',
#  'Hypotension, Sepsis event, Tachycardia',
#  'Hypertension, Increased Oxygen Need, Sepsis event, Tachycardia, Tachypnea',
#  'Hypertension, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Tachypnea',
#  'Hypotension, Tachycardia',
#  'Staff concerned/Worried about Patient, Chest pain',
#  'Hypotension, Sepsis event, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypertension',
#  'Low O2 Saturation',
#  'Other: iv',
#  'Other: fever with rigors',
#  'Other: pain pump interrogation',
#  'Hypertension, Increased Oxygen Need, Low O2 Saturation, Tachypnea',
#  'Bradycardia',
#  'Staff concerned/Worried about Patient, Arrythmias',
#  'Other: iv start',
#  'Hypotension, Increased Oxygen Need, Low O2 Saturation, Sepsis event, Tachycardia, Tachypnea',
#  'Changes in LOC',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Staff concerned/Worried about Patient, Changes in LOC, Loss of consciousness, Sepsis event',
#  'Staff concerned/Worried about Patient, Hypertension, Tachycardia, Tachypnea',
#  'Other: iv start attempted',
#  'Changes in LOC',
#  'Other: tele tech noted that there was some ST changes.  alerted primary RN as well as RRT.',
#  'Sepsis event',
#  'Arrythmias, Increased Oxygen Need, Low O2 Saturation, Tachycardia',
#  'Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Hypotension, Tachycardia',
#  'Other: iv start',
#  'Staff concerned/Worried about Patient, Chest pain, Increased Oxygen Need',
#  'Other: iv start',
#  'Staff concerned/Worried about Patient, Hypertension',
#  'Staff concerned/Worried about Patient, Tachycardia',
#  'Hypotension',
#  'Staff concerned/Worried about Patient',
#  'Increased Oxygen Need, Tachypnea',
#  'Staff concerned/Worried about Patient, Hypotension',
#  'Other: IV START',
#  'Other: iv start',
#  'Other: iv start',
#  'Chest pain, Tachycardia, Tachypnea',
#  'Staff concerned/Worried about Patient, Low O2 Saturation',
#  'Other: ST depression and t wave inversion',
#  'Hypertension, Other: iv start',
#  'Staff concerned/Worried about Patient, Sepsis event, Tachycardia',
#  'Hypertension',
#  'Hypotension, Tachycardia',
#  'Other: Dressing change',
#  ...]

# %% [markdown]
# ### Number of reasons given (note, not all rrt events have reasons given; we have 2048 rrt events)

# %%
len(reasons)
# Out:
# 1942

# %% [markdown]
# ### Number of reasons with "Other: ..." reason provided (user filled)

# %%
count_others(reasons)
# Out:
# defaultdict(<type 'int'>, {'other_withothers': 199, 'only_other': 169})

# %% [markdown]
# #### This means 169/2048 => 8.3% of reasons have only a personnel-specified reason listed

# %% [markdown]
# ### Number of reasons including "Staff Concern" as a reason, by itself & with others

# %%
count_staffconcern(reasons)
# Out:
# defaultdict(<type 'int'>, {'with_other_reasons': 583, 'by_itself': 111})

# %% [markdown]
# #### This means 111/2048 => 5.4% of all RRTs have no specific reason provided

# %% [markdown]
# ### Average number of reasons per RRT call:

# %%
avg_num_reasons(reasons)
# Out:
# 2.0036045314109168

# %% [markdown]
# ### Count the occurrences -- what are the most frequent reasons?

# %%
df_reasons = find_rrt_freq(reasons)

# %%
df_reasons
# Out:
#                                                  index  count
# 0                staff concerned/worried about patient    694
# 1                                            tachypnea    446
# 2                                    low o2 saturation    349
# 3                                          tachycardia    345
# 4                                increased oxygen need    332
# 5                                          hypotension    327
# 6                                       changes in loc    263
# 7                                           chest pain    181
# 8                                           arrythmias    115
# 9                                         sepsis event     72
# 10                                        hypertension     69
# 11                              suspected stroke/acute     63
# 12                                             seizure     52
# 13                                         bradycardia     49
# 14                                      acute bleeding     48
# 15                               loss of consciousness     44
# 16                                           bradypnea     32
# 17                                     other: iv start     30
# 18                                         blood sugar     25
# 19                                other: increased wob      6
# 20                                    other: code blue      6
# 21                                other: resp. decomp.      6
# 22                                          other: sob      5
# 23                                     other: wheezing      5
# 24                                          other: raf      5
# 25                                      other: febrile      4
# 26                      other: pain pump interrogation      4
# 27                                  other: stroke code      4
# 28                         other: resp. decompensation      3
# 29          other: intrathecal pain pump interrogation      3
# ..                                                 ...    ...
# 259                                      other: high k      1
# 260         other: facial swelling, concern for airway      1
# 261                                        other: fall      1
# 262                                  other: febrile 38      1
# 263                                 other: febrile >39      1
# 264                           other: fever with rigors      1
# 265                         other: fever, leukocytosis      1
# 266                               other: fever, rigors      1
# 267                                    other: gi bleed      1
# 268                            other: hd cath removal.      1
# 269                other: headache, nausea with emesis      1
# 270                other: heartmate ii red heart alarm      1
# 271                                  other: hemoptysis      1
# 272                      other: high fever with rigors      1
# 273  other: high volume use of opioids and benzodia...      1
# 274                          other: increased lethargy      1
# 275                                 other: hypercapnec      1
# 276                               other: hypertiensive      1
# 277                                other: hypoglycemia      1
# 278  other: hypoglycemia with decreaased loc, diaph...      1
# 279  other: hypotension after beta blockade given f...      1
# 280                    other: hypotension after ntg sl      1
# 281                                   other: hypoxemia      1
# 282                                     other: hypoxic      1
# 283   other: inability to clear airway with suctioning      1
# 284       other: inability to effectively clear airway      1
# 285  other: inadvertent disconnection of epidural c...      1
# 286                            other: increase in pain      1
# 287                       other: increased hematemesis      1
# 288             other: iv start needed for antibiotics      1
#
# [289 rows x 2 columns]

# %% [markdown]
# ## Staff concern for patient is the top reason for RRT.

# %% [markdown]
# ### Visualize the top 15 reaons

# %%
plt.figure(figsize=(12,8))
plt.tight_layout
val = df_reasons['count'][0:15]
pos = np.arange(15)+0.5 #bar centers on the y axis
plt.barh(-pos, val, align='center')
plt.yticks(-pos, df_reasons['index'][0:15])
plt.tick_params(direction='in', labelsize='16', pad=1)
plt.xlabel('Frequency of Reason', fontsize='16')
plt.title('Top Reasons for RRT Event, Jan 2015 - Aug 2016', fontsize = '16')
plt.tight_layout()
# plt.savefig('RRT_top15reasons.png')
# Out:
# <img src="data:image/png;base64,...">
